# %%
import GPy
import numpy as np

X1 = np.random.uniform(-3.,3.,(20,1))
X2 = np.random.uniform(8.,100.,(20,1))
Y1 = np.sin(X1-5) + np.random.randn(20,1)*.25 + 1
Y2 = np.sin(X2) + np.random.randn(20,1)*0.05

X = np.r_[X1,X2]
Y = np.r_[Y1, Y2]

kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=1.)
GPy.kern.BasisFuncKernel?

# %%
m = GPy.models.GPRegression(X,Y,kernel)
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 52.52659130816759<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
m.plot()
# Out:
# {'dataplot': [<matplotlib.collections.PathCollection at 0x1e4e7e08>],
#  'gpmean': [[<matplotlib.lines.Line2D at 0x1e5affd0>]],
#  'gpconfidence': [<matplotlib.collections.PolyCollection at 0x1e5b8e68>]}

# %%
m.optimize()
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 32.513988295814315<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>               value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  0.7132233478687384</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.4538312259921602</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.060059425443378556</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
f=m.plot()
f
# Out:
# {'dataplot': [<matplotlib.collections.PathCollection at 0x1e5b4370>],
#  'gpmean': [[<matplotlib.lines.Line2D at 0x1e5b4e68>]],
#  'gpconfidence': [<matplotlib.collections.PolyCollection at 0x1e5b44c0>]}

# %%
# sample inputs and outputs
X = np.random.uniform(-3.,3.,(50,2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*0.05

# define kernel
ker = GPy.kern.Matern52(2,ARD=True) + GPy.kern.White(2)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# optimize and plot
m.optimize(messages=True,max_f_eval = 1000)
fig = m.plot()
m
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
#  c:\users\cbaker1\venv\lib\site-packages\GPy\plotting\matplot_dep\plot_definitions.py:184: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -24.45520159625845<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.Mat52.variance     </td><td class=tg-right>   0.3853293166028461</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Mat52.lengthscale  </td><td class=tg-right>                 (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.white.variance     </td><td class=tg-right>0.0007674873805185786</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0007674873805185786</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
X = np.random.uniform(-3.,3.,(50,20))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*0.05

# define kernel
ker = GPy.kern.Matern52(2,ARD=True) + GPy.kern.White(2)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# optimize and plot
m.optimize(messages=True,max_f_eval = 1000)
m
# Out:
#  c:\users\cbaker1\venv\lib\site-packages\GPy\core\gp.py:87: UserWarning:Your kernel has a different input dimension 2 then the given X dimension 20. Be very sure this is what you want and you have not forgotten to set the right input dimenion in your kernel
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -25.948494776602516<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                 value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.Mat52.variance     </td><td class=tg-right>    0.4571018437079128</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Mat52.lengthscale  </td><td class=tg-right>                  (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.white.variance     </td><td class=tg-right>0.00042521681073169105</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.00042521681073169105</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
print(Y)
m.predict(X)
# Out:
# [[ 0.16082163]
#  [-0.59434796]
#  [-0.39183679]
#  [-0.38344777]
#  [ 0.93801858]
#  [ 0.09678312]
#  [ 0.47020452]
#  [-0.1430275 ]
#  [ 0.11521574]
#  [-0.38902626]
#  [ 0.16284829]
#  [ 0.37950177]
#  [-0.26800441]
#  [-0.5448991 ]
#  [ 0.88347651]
#  [-0.07564648]
#  [ 0.66897314]
#  [-0.803091  ]
#  [ 0.58831289]
#  [-0.21690223]
#  [-0.93915864]
#  [-0.28184111]
#  [ 0.37517749]
#  [ 0.51160006]
#  [-0.18992293]
#  [-0.03945173]
#  [-0.39539574]
#  [-0.67573181]
#  [-0.05028674]
#  [-0.43149547]
#  [ 0.73457871]
#  [ 0.21738327]
#  [ 0.44483927]
#  [-0.64029333]
#  [-0.06606144]
#  [ 0.88526566]
#  [ 0.18214886]
#  [ 0.437867  ]
#  [ 0.88515669]
#  [ 0.30543993]
#  [-0.0572355 ]
#  [-0.31856613]
#  [ 0.44220121]
#  [ 0.4269478 ]
#  [ 0.09163785]
#  [-0.08384237]
#  [-0.46866001]
#  [-0.40589924]
#  [-0.08191676]
#  [-0.49255622]]
# (array([[ 0.16043568],
#         [-0.61057671],
#         [-0.40057462],
#         [-0.4238346 ],
#         [ 0.93419642],
#         [ 0.10909553],
#         [ 0.4616771 ],
#         [-0.13322643],
#         [ 0.10852643],
#         [-0.39625615],
#         [ 0.16573275],
#         [ 0.40550307],
#         [-0.27445544],
#         [-0.5309113 ],
#         [ 0.88890711],
#         [-0.08206161],
#         [ 0.64887563],
#         [-0.7893217 ],
#         [ 0.58319816],
#         [-0.2336715 ],
#         [-0.92796645],
#         [-0.29048635],
#         [ 0.38592334],
#         [ 0.52103052],
#         [-0.18452037],
#         [-0.04486979],
#         [-0.39668653],
#         [-0.67756645],
#         [-0.05326068],
#         [-0.42192347],
#         [ 0.72648521],
#         [ 0.22228489],
#         [ 0.41025836],
#         [-0.62728157],
#         [-0.06880845],
#         [ 0.88755618],
#         [ 0.17029021],
#         [ 0.43037478],
#         [ 0.87823128],
#         [ 0.30026923],
#         [-0.04218026],
#         [-0.32246189],
#         [ 0.45052812],
#         [ 0.44084026],
#         [ 0.10580544],
#         [-0.08273181],
#         [-0.43194235],
#         [-0.39836209],
#         [-0.08191507],
#         [-0.4920699 ]]),
#  array([[0.00164895],
#         [0.00155949],
#         [0.00167053],
#         [0.00116983],
#         [0.00164743],
#         [0.0014976 ],
#         [0.00151751],
#         [0.00151909],
#         [0.00159873],
#         [0.00150509],
#         [0.00160344],
#         [0.00133452],
#         [0.00153438],
#         [0.00157899],
#         [0.0015943 ],
#         [0.00160642],
#         [0.00146223],
#         [0.00147531],
#         [0.00163572],
#         [0.00132366],
#         [0.00159514],
#         [0.0015763 ],
#         [0.00140681],
#         [0.00155173],
#         [0.00140851],
#         [0.00150389],
#         [0.0016849 ],
#         [0.0016166 ],
#         [0.0014567 ],
#         [0.00159586],
#         [0.00148321],
#         [0.00169004],
#         [0.00138107],
#         [0.00161238],
#         [0.00165005],
#         [0.00157592],
#         [0.00149735],
#         [0.00136077],
#         [0.00151572],
#         [0.00156092],
#         [0.00158394],
#         [0.00142148],
#         [0.00164538],
#         [0.00152388],
#         [0.00161102],
#         [0.00169153],
#         [0.00122572],
#         [0.00147575],
#         [0.00142548],
#         [0.00151768]]))
